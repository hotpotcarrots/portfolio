# %% [raw]
# ---
# layout: post
# title: Data Abstraction Homework
# description: Quick practice with Python lists
# permalink: /csp/big-idea-3/dataabstraction/p3/homework
# ---

# %% [markdown]
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <title>Data Abstraction Hack Homework</title>
#   <style>
#     body {
#       font-family: Arial, sans-serif;
#       padding: 20px;
#       background-color: #000;   /* black background */
#       color: #f4f4f4;           /* light text */
#     }
#     h1 { color: #f39c12; }       /* golden orange for title */
#     h2 { margin-top: 30px; color: #1abc9c; } /* teal for subtitles */
#     .output {
#       background: #222;          /* dark gray output box */
#       padding: 15px;
#       border-radius: 8px;
#       color: #fff;
#     }
#     code, pre {
#       background: #333;
#       color: #0f0;               /* green code text */
#       padding: 5px;
#       border-radius: 5px;
#     }
#     .instructions p, .instructions li {
#       color: #ffffff;
#     }
#     .hack-instructions p,
#     .hack-instructions ul,
#     .hack-instructions li {
#       color: #ffffff;
#     }
#   </style>
# </head>
# <body>
#   <h1>📝 Data Abstraction Hack (10 minutes)</h1>
#
#   <h2 class="instructions">Instructions</h2>
#   <div class="instructions">
#     <p>
#       In this activity, you’ll learn how <strong>lists</strong> manage data and
#       reduce complexity in programs. Follow these steps:
#     </p>
#     <ol>
#       <li>Edit the <code>students</code> list to use your own names (friends, classmates, etc.).</li>
#       <li>Edit the <code>scores</code> list to assign each student a score of your choice.</li>
#       <li>Save and refresh the page in your browser to see how the output changes automatically.</li>
#       <li>After experimenting with <code>students</code> and <code>scores</code>, complete the 🚀 Hack Challenge at the bottom.</li>
#       <li>To make edits, open <strong>VS Code</strong> and find the file at <code>notebooks/csp/big-ideas/2025-09-26-bigidea32homework.ipymd</code>.</li>
#     </ol>
#   </div>
#
#   <h2>Class Roster Output:</h2>
#   <div id="output" class="output"></div>
#
#   <script>
#     // A list (array) of students
#     let students = ["Aneesh", "Perry", "Moiz"];  // TODO: change these names
#
#     // A list of scores
#     let scores = [85, 90, 87];  // TODO: change these scores
#
#     // String to build output
#     let out = "";
#
#     // 1. Print roster
#     out += "<p><strong>Students:</strong> " + students.join(", ") + "</p>";
#
#     // 2. Print first student and score
#     out += "<p><strong>First student:</strong> " + students[0] + " - " + scores[0] + "</p>";
#
#     // 3. Add a new student + score
#     students.push("Tanay");
#     scores.push(95);
#
#     out += "<p><strong>After adding Tanay:</strong> " + students.join(", ") + "</p>";
#
#     // 4. Remove a student who transfers out
#     let index = students.indexOf("Moiz");
#     if (index !== -1) {
#       students.splice(index, 1);
#       scores.splice(index, 1);
#     }
#
#     out += "<p><strong>After removing Moiz:</strong> " + students.join(", ") + "</p>";
#
#     // 5. Curve all scores by +5
#     for (let i = 0; i < scores.length; i++) {
#       scores[i] += 5;
#     }
#
#     // 6. Print each student with score
#     out += "<h3>Final Scores</h3>";
#     for (let i = 0; i < students.length; i++) {
#       out += "<p>" + students[i] + " - " + scores[i] + "</p>";
#     }
#
#     // Show results
#     document.getElementById("output").innerHTML = out;
#   </script>
#
#   <h2>🚀 Hack Challenge</h2>
#   <div class="hack-instructions">
#     <p>
#       Now that you’ve practiced with <code>students</code> and <code>scores</code>,
#       it’s your turn! Create <strong>one new list of your choice</strong>.
#     </p>
#     <p>
#       ✅ Ideas:
#     </p>
#     <ul>
#       <li>A list of <code>favoriteFoods</code></li>
#       <li>A list of <code>cities</code> you want to visit</li>
#       <li>A list of <code>videoGames</code> you enjoy</li>
#     </ul>
#     <p>
#       After creating your new list, write a loop to print each element to the page.
#     </p>
#   </div>
#
#   <pre>
# // Example structure:
# let favoriteSports = ["Basketball", "Swimming", "Boxing"];
#
# for (let i = 0; i < favoriteSports.length; i++) {
#   console.log(favoriteSports[i]); // Replace console.log with output to the page if you like
# }
#   </pre>
#
#   <p>
#     💡 Hint: Use the same pattern you saw with <code>students</code> and <code>scores</code>.
#   </p>
# </body>
# </html>

# %% [markdown]
# <style>
#   .output { background: #222; padding: 15px; border-radius: 8px; color: #fff; }
#   code, pre { background: #333; color: #0f0; padding: 5px; border-radius: 5px; }
# </style>
#
# <h1>Favorite Food Output:</h1>
# <div id="output-food" class="output"></div>
#
# <script>
#   (function() {
#     // isolate variables so they don't conflict with other cells
#     let foods = ["pizza", "burger", "pasta"];
#     let foodScores = [82, 93, 89];
#     let out = "";
#
#     out += "<p><strong>Foods:</strong> " + foods.join(", ") + "</p>";
#     out += "<p><strong>First food:</strong> " + foods[0] + " - " + foodScores[0] + "</p>";
#
#     foods.push("sushi");
#     foodScores.push(95);
#     out += "<p><strong>After adding sushi:</strong> " + foods.join(", ") + "</p>";
#
#     let idx = foods.indexOf("pasta");
#     if (idx !== -1) {
#       foods.splice(idx, 1);
#       foodScores.splice(idx, 1);
#     }
#     out += "<p><strong>After removing pasta:</strong> " + foods.join(", ") + "</p>";
#
#     for (let i = 0; i < foodScores.length; i++) {
#       foodScores[i] += 5;
#     }
#
#     out += "<h3>Final Scores</h3>";
#     for (let i = 0; i < foods.length; i++) {
#       out += "<p>" + foods[i] + " - " + foodScores[i] + "</p>";
#     }
#
#     document.getElementById("output-food").innerHTML = out;
#   })();
# </script>
